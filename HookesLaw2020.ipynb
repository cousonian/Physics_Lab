# %% [markdown]
# # Method 1:  Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([100,133,149,160,200,250])/1000
x1 = np.array([33.5,44.5,49.5,53,66,82.5])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Small k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 3.01 N/m
# Error in slope = 0.03 N/m
# Goodness of fit = 0.71

# %%
import physplot as phys
import numpy as np

#spring 2
m2 = np.array([100,133,149,160,200,250])/1000
x2 = np.array([9.5,11,13,13.5,17,25])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x2,m2*9.8,errm*9.8,'Large k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 9.06 N/m
# Error in slope = 0.08 N/m
# Goodness of fit = 616.93

# %%
import physplot as phys
import numpy as np

#spring 1
T_squared = np.array([.5,.592,.632,.726,.812,.925])**2
m1 = np.array([100,133,149,160,200,250])/1000
errT = np.array([5,5,5,5,5,5])/100

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(m1,T_squared,errT,'Large k spring','m(kg)','T^2(seconds^2)','N/m')

c=(4*((np.pi)**2))
# Out:
# Slope = 4.17 N/m
# Error in slope = 0.42 N/m
# Goodness of fit = 1.66

# %%
import physplot as phys
import numpy as np

#spring 1
T_squared = np.array([1.03,1.326,1.408,1.457,1.632,1.825])**2
m1 = np.array([100,133,149,160,200,250])/1000
errT = np.array([5,5,5,5,5,5])/100

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(m1,T_squared,errT,'Small k spring','m(kg)','T^2(seconds^2)','N/m')
# Out:
# Slope = 14.63 N/m
# Error in slope = 0.42 N/m
# Goodness of fit = 14.17

# %%
print(c/4.17)
print(c/14.63)
# Out:
# 9.467246427903461
# 2.6984564322869056

# %%
print(c/.42)
# Out:
# 93.99623239132723
